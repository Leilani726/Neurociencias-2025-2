# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
size = 1000
x = np.random.normal(loc=0, scale=8, size=size)
y = np.random.normal(loc=0, scale=2, size=size)

# %%
plt.scatter(x, y)
plt.axis('equal')
plt.show()

# %%
mean = [0, 0]
cov = [[3, 3], [3, 4]]
size = 500
X = np.random.multivariate_normal(mean=mean, cov=cov, size=size)

# %%
plt.scatter(X[:, 0], X[:, 1])
plt.axis('equal')
plt.show()

# %%
X
# Out:
# array([[-1.09520716, -1.3830411 ],
#        [ 3.65483001,  2.7075523 ],
#        [ 0.98786221,  1.38182229],
#        ...,
#        [-0.52905146, -0.68165017],
#        [-0.5293319 , -1.03736687],
#        [-2.2036709 , -1.67898396]])

# %% [markdown]
# ## normalización de los datos

# %%
np.mean(X, axis=0), np.std(X, axis=0)
# Out:
# (array([0.06961925, 0.17936716]), array([1.80061073, 2.0843607 ]))

# %%
X_std = (X - np.mean(X, axis=0))/np.std(X, axis=0)

# %%
plt.scatter(X_std[:, 0], X_std[:, 1])

# %% [markdown]
# # Calculo de la covarianza

# %%
X_mean = np.mean(X_std, axis=0)
X_mean
# Out:
# array([ 1.04360964e-17, -6.46149800e-17])

# %%
cov_matrix = (X_std - X_mean).T.dot((X_std - X_mean))/(X_std.shape[0]-1)
cov_matrix
# Out:
# array([[1.00200401, 0.88087167],
#        [0.88087167, 1.00200401]])

# %%
np.cov(X_std.T)
# Out:
# array([[1.00200401, 0.88087167],
#        [0.88087167, 1.00200401]])

# %%
eig_vals, eig_vecs = np.linalg.eig(cov_matrix)
eig_vals, eig_vecs
# Out:
# (array([1.88287568, 0.12113233]),
#  array([[ 0.70710678, -0.70710678],
#         [ 0.70710678,  0.70710678]]))

# %% [markdown]
# # Calculo de valores y vectores propios con la matriz de correlación

# %%
corr_matrix = np.corrcoef(X_std.T)
corr_matrix
# Out:
# array([[1.        , 0.87910993],
#        [0.87910993, 1.        ]])

# %%
eig_vals_corr, eig_vecs_corr = np.linalg.eig(corr_matrix)
eig_vals_corr, eig_vecs_corr
# Out:
# (array([1.87910993, 0.12089007]),
#  array([[ 0.70710678, -0.70710678],
#         [ 0.70710678,  0.70710678]]))

# %% [markdown]
# # Singular Value Decomposition

# %%
u, s, v = np.linalg.svd(X_std.T)
u
# Out:
# array([[-0.70710678, -0.70710678],
#        [-0.70710678,  0.70710678]])
